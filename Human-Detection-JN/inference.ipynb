# %%
# !python -V
# Out:
# Python 3.10.19

# %%
from ultralytics import YOLO

# %%
model=YOLO('yolov8n.pt')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 14.3MB/s 0.4s.4s<0.1s

# %%
result = model.predict(source=0, show=True, classes=0,iou=0)
# Out:
# Warning: Ignoring XDG_SESSION_TYPE=wayland on Gnome. Use QT_QPA_PLATFORM=wayland to run on Wayland anyway.
# QFontDatabase: Cannot find font directory /opt/software/miniconda3/envs/py310/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /opt/software/miniconda3/envs/py310/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /opt/software/miniconda3/envs/py310/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /opt/software/miniconda3/envs/py310/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /opt/software/miniconda3/envs/py310/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# 1/1: 0... Success ✅ (inf frames of shape 640x480 at 30.00 FPS)
#
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 480x640 (no detections), 613.0ms
# 0: 480x640 (no detections), 632.5ms
# 0: 480x640 (no detections), 312.2ms
# 0: 480x640 (no detections), 291.1ms
# 0: 480x640 (no detections), 233.4ms
# 0: 480x640 (no detections), 256.3ms
# 0: 480x640 (no detections), 246.8ms
# 0: 480x640 (no detections), 227.2ms
# 0: 480x640 (no detections), 268.6ms
# 0: 480x640 (no detections), 257.8ms
# 0: 480x640 (no detections), 276.3ms
# 0: 480x640 (no detections), 271.6ms
# 0: 480x640 (no detections), 257.2ms
# 0: 480x640 (no detections), 311.0ms
# 0: 480x640 (no detections), 265.1ms
# 0: 480x640 (no detections), 185.8ms
# 0: 480x640 (no detections), 265.1ms
# 0: 480x640 (no detections), 220.7ms
# 0: 480x640 (no detections), 237.1ms
# 0: 480x640 (no detections), 273.5ms
# Speed: 6.6ms preprocess, 293.3ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)

# %%
r=result[0]

# %%
 
model = YOLO('yolov8n.pt')
model.export(format='onnx', opset=12,dynamic=False, simplify=True, batch=12, imgsz=(640,640))     # Handle different input sizes
# Out:
# Ultralytics 8.4.14 🚀 Python-3.10.19 torch-2.5.1+cu121 CPU (Intel Core i7-7820HQ 2.90GHz)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# PyTorch: starting from 'yolov8n.pt' with input shape (12, 3, 640, 640) BCHW and output shape(s) (12, 84, 8400) (6.2 MB)
#
# ONNX: starting export with onnx 1.20.1 opset 12...
# ONNX: slimming with onnxslim 0.1.86...
# ONNX: export success ✅ 6.4s, saved as 'yolov8n.onnx' (12.3 MB)
#
# Export complete (13.1s)
# Results saved to /home/ajinkya/Desktop/ML/Edge-AI/Human-Detection-JN
# Predict:         yolo predict task=detect model=yolov8n.onnx imgsz=640
# Validate:        yolo val task=detect model=yolov8n.onnx imgsz=640 data=coco.yaml
# Visualize:       https://netron.app
# 'yolov8n.onnx'

# %%
# !python -V
# Out:
# Python 3.10.19

# %%
from ultralytics import YOLO

# %%
model=YOLO('yolo11n.pt')

# %%
result = model.predict(source=0, show=True, classes=0,iou=0)

# %%
r=result[0]

# %%
 
model = YOLO('yolo11n.pt')
model.export(format='onnx', opset=12,dynamic=False, simplify=True, batch=12, imgsz=(640,640))     # Handle different input sizes
# Out:
# Ultralytics 8.4.14 🚀 Python-3.10.19 torch-2.5.1+cu121 CPU (Intel Core i7-7820HQ 2.90GHz)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# PyTorch: starting from 'yolo11n.pt' with input shape (12, 3, 640, 640) BCHW and output shape(s) (12, 84, 8400) (5.4 MB)
#
# ONNX: starting export with onnx 1.20.1 opset 12...
# ONNX: slimming with onnxslim 0.1.86...
# ONNX: export success ✅ 7.6s, saved as 'yolo11n.onnx' (10.2 MB)
#
# Export complete (15.3s)
# Results saved to /home/ajinkya/Desktop/ML/Edge-AI/Human-Detection-JN
# Predict:         yolo predict task=detect model=yolo11n.onnx imgsz=640
# Validate:        yolo val task=detect model=yolo11n.onnx imgsz=640 data=/usr/src/ultralytics/ultralytics/cfg/datasets/coco.yaml
# Visualize:       https://netron.app
# 'yolo11n.onnx'
